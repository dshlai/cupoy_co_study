# %% [markdown]
# ## Login into Raspberry Pi using SSH
#
# ![image.png](attachment:image.png)
#
#
# ## Download using wget, then "ls -al" to check if download is successful
#
# ![image-2.png](attachment:image-2.png)
#
#
# ## CD to "/", compress "/opt" using tar, then uncompress it into "/tmp"
#
# ![image-3.png](attachment:image-3.png)
